# %%
from tkinter import *

window = Tk()

window.title('Calculator')
window.geometry('400x400')
t1 = Label(text = 'Mini Calculations')
t1.pack()



l1 = Label(text = 'n1',fg = 'white',bg = 'black')
l1.place(x=10,y=50)
e1 = Entry(bg = 'yellow')
e1.place(x=50,y=50)




l2 = Label(text = 'n2',fg = 'white',bg = 'black')
l2.place(x=10,y=50)
e2 = Entry(bg = 'yellow')
e2.place(x=50,y=50)


l3 = Label(text='Result',bg = 'green', fg = 'black')
l3.place(x=20,y=100)
e3 = Entry(bg='white',fg='red')
e3.place(x=100,y=130)


b1 = Button(text='Add',bg='grey',fg='blue')
b1.place()
window.mainloop()

# %%
from tkinter import *

window = Tk()

window.title('Calculator')
window.geometry('400x400')
t1 = Label(text = 'Mini Calculations')
t1.pack()


l1 = Label(text = 'n1',fg = 'white',bg = 'black')
l1.place(x=10,y=20)
e1 = Entry(bg = 'yellow')
e1.place(x=50,y=20)


l2 = Label(text = 'n2',fg = 'white',bg = 'black')
l2.place(x=10,y=50)
e2 = Entry(bg = 'yellow')
e2.place(x=50,y=50)


l3 = Label(text='Result',bg = 'green', fg = 'black')
l3.place(x=20,y=100)
e3 = Entry(bg='white',fg='red')
e3.place(x=70,y=100)


#
def add():
    n1  = int(e1.get())
    n2  = int(e2.get())
    res = n1 + n2
    e3.insert(0,str(res))
    print(res)
    

b1 = Button(text='Add',bg='grey',fg='blue')
b1.place(x=100,y=130)
window.mainloop()

# %%
from tkinter impoort *
import calendar

def showCalendar():
    gui = Tk()
    gui.config(background = 'grey')
    gui.title("Calendar of the year")
    gui.geometry("550x600")
    year = int(year_field.get())
    gui_content = calendar.calendar(year)
    calyear = Label(gui,text = gui_content, font = "Consolas 10 bold")
    callYear.grid(row=5, column = 1, padx = 20)
    gui.mainloop()
    
    
if __name__=='__main__':
    new = Tk()
    new.config(background='grey')
    new.title("Calendar")
    new.geometry("250x140")
# Out:
#   File "C:\Users\santo\AppData\Local\Temp\ipykernel_21024\4077153279.py", line 1
#     from tkinter impoort *
#                  ^
# SyntaxError: invalid syntax

# %%
from tkinter import *
from tkinter.ttk import *


from time import strftime



root = Tk()
root.title("World's Class Digital CLock")


def time():
    string = strftime('%H:%M:%S: %p')
    label.config(text=string)
    label.after(1000,time)
    
    
label = Label(root , font=("ds-digital",200),background="white",foreground="black")
label.pack(anchor='center')
time()
mainloop()

# %%
# Import Required Library
from tkinter import *
from PyDictionary import PyDictionary

# Create Objects
dictionary = PyDictionary()
root = Tk()

# Set geometry
root.geometry("400x400")


def dict():
	meaning.config(text=dictionary.meaning(word.get())['Noun'][0])
	synonym.config(text=dictionary.synonym(word.get()))
	antonym.config(text=dictionary.antonym(word.get()))


# Add Labels, Button and Frames
Label(root, text="Dictionary", font=(
	"Helvetica 20 bold"), fg="Green").pack(pady=10)

# Frame 1
frame = Frame(root)
Label(frame, text="Type Word", font=("Helvetica 15 bold")).pack(side=LEFT)
word = Entry(frame, font=("Helvetica 15 bold"))
word.pack()
frame.pack(pady=10)

# Frame 2
frame1 = Frame(root)
Label(frame1, text="Meaning:- ", font=("Helvetica 10 bold")).pack(side=LEFT)
meaning = Label(frame1, text="", font=("Helvetica 10"))
meaning.pack()
frame1.pack(pady=10)

# Frame 3
frame2 = Frame(root)
Label(frame2, text="Synonym:- ", font=("Helvetica 10 bold")).pack(side=LEFT)
synonym = Label(frame2, text="", font=("Helvetica 10"))
synonym.pack()
frame2.pack(pady=10)

# Frame 4
frame3 = Frame(root)
Label(frame3, text="Antonym:- ", font=("Helvetica 10 bold")).pack(side=LEFT)
antonym = Label(frame3, text="", font=("Helvetica 10"))
antonym.pack(side=LEFT)
frame3.pack(pady=10)

Button(root, text="Submit", font=("Helvetica 15 bold"), command=dict).pack()

# Execute Tkinter
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17136\1918186346.py in <module>
#       1 # Import Required Library
#       2 from tkinter import *
# ----> 3 from PyDictionary import PyDictionary
#       4
#       5 # Create Objects
#
# ModuleNotFoundError: No module named 'PyDictionary'
